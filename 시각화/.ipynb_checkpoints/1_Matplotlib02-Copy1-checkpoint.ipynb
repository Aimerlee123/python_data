# %% [markdown]
# # 맵플롯립 Matplotlib

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':  # 맥OS 
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':  # 윈도우
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system...  sorry~~~')

# %% [markdown]
# ## 3. 히스토그램 : hist()

# %% [markdown]
# - 연속형 수치형 데이터의 분포 시각화
# - 참고. 막대그래프는 범주형 데이터의 빈도(비율) 분포 시각화

# %%
import numpy as np

np.random.seed(10)
x = np.random.randn(1000)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
plt.title('Std.Normal Distribution')
plt.hist(x)
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.title('Std.Normal Distribution')
plt.hist(x, bins=20)
plt.show()

# %%
plt.figure(figsize=(4,3))
plt.title('Std.Normal Distribution')
plt.hist(x, bins=20, orientation='horizontal')
plt.show()

# %%
import pandas as pd

# %%
df = pd.read_csv('data/auto_mpg.csv', header=None)
df.head()
# Out:
#       0  1      2      3       4     5   6  7                          8
# 0  18.0  8  307.0  130.0  3504.0  12.0  70  1  chevrolet chevelle malibu
# 1  15.0  8  350.0  165.0  3693.0  11.5  70  1          buick skylark 320
# 2  18.0  8  318.0  150.0  3436.0  11.0  70  1         plymouth satellite
# 3  16.0  8  304.0  150.0  3433.0  12.0  70  1              amc rebel sst
# 4  17.0  8  302.0  140.0  3449.0  10.5  70  1                ford torino

# %%
df.columns = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
              'accel', 'model_year', 'origin', 'name']
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  accel  model_year  \
# 0  18.0          8         307.0      130.0  3504.0   12.0          70
# 1  15.0          8         350.0      165.0  3693.0   11.5          70
# 2  18.0          8         318.0      150.0  3436.0   11.0          70
# 3  16.0          8         304.0      150.0  3433.0   12.0          70
# 4  17.0          8         302.0      140.0  3449.0   10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    float64
#  5   accel         398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
df.horsepower.unique()
# Out:
# array(['130.0', '165.0', '150.0', '140.0', '198.0', '220.0', '215.0',
#        '225.0', '190.0', '170.0', '160.0', '95.00', '97.00', '85.00',
#        '88.00', '46.00', '87.00', '90.00', '113.0', '200.0', '210.0',
#        '193.0', '?', '100.0', '105.0', '175.0', '153.0', '180.0', '110.0',
#        '72.00', '86.00', '70.00', '76.00', '65.00', '69.00', '60.00',
#        '80.00', '54.00', '208.0', '155.0', '112.0', '92.00', '145.0',
#        '137.0', '158.0', '167.0', '94.00', '107.0', '230.0', '49.00',
#        '75.00', '91.00', '122.0', '67.00', '83.00', '78.00', '52.00',
#        '61.00', '93.00', '148.0', '129.0', '96.00', '71.00', '98.00',
#        '115.0', '53.00', '81.00', '79.00', '120.0', '152.0', '102.0',
#        '108.0', '68.00', '58.00', '149.0', '89.00', '63.00', '48.00',
#        '66.00', '139.0', '103.0', '125.0', '133.0', '138.0', '135.0',
#        '142.0', '77.00', '62.00', '132.0', '84.00', '64.00', '74.00',
#        '116.0', '82.00'], dtype=object)

# %%
# hp = df.horsepower.astype(float)

# %%
df.mpg.describe()
# Out:
# count    398.000000
# mean      23.514573
# std        7.815984
# min        9.000000
# 25%       17.500000
# 50%       23.000000
# 75%       29.000000
# max       46.600000
# Name: mpg, dtype: float64

# %%
plt.figure(figsize=(4,3))
plt.title('MPG Dist.')
plt.hist(df.mpg)
plt.xlabel('mpg')
plt.show()

# %% [markdown]
# #### 문제.
#
# auto-mpg 데이터셋에서 4개의 변수('mpg', 'cylinders', 'displacement', 'weight')에 대한 히스토그램을 한 그림에 그리기

# %%
cols = df.columns[[0,1,2,4]]
fig, axs = plt.subplots(2,2)
for i in range(2):
    for j in range(2):
        col = cols[2*i + j]
#         print(col)
        axs[i,j].hist(df[col])
        axs[i,j].set_title(col)
plt.tight_layout()
plt.show()

# %%
cols = df.columns[[0,1,2,4]]
fig, axs = plt.subplots(2,2)
for i in range(2):
    for j in range(2):
        col = cols[2*i + j]
#         print(col)
        axs[i,j].hist(np.log(df[col]))
        axs[i,j].set_title(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. 박스플롯 : boxplot()

# %% [markdown]
# - 데이터의 분포를 파악해주는 플롯
#     - 최소값, 제1사분위수, 중위수, 제3사분위수, 최대값
#
# - 이상치 데이터 탐색을 위해 사용

# %%
df[cols].describe()
# Out:
#               mpg   cylinders  displacement       weight
# count  398.000000  398.000000    398.000000   398.000000
# mean    23.514573    5.454774    193.425879  2970.424623
# std      7.815984    1.701004    104.269838   846.841774
# min      9.000000    3.000000     68.000000  1613.000000
# 25%     17.500000    4.000000    104.250000  2223.750000
# 50%     23.000000    4.000000    148.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  3608.000000
# max     46.600000    8.000000    455.000000  5140.000000

# %%
plt.figure(figsize=(4,4))
plt.boxplot(df.mpg)
plt.xticks([1], ['mpg'])
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.boxplot(df[cols])
plt.show()

# %%
cols = df.columns[[0,1,2,4]]
fig, axs = plt.subplots(2,2)
for i in range(2):
    for j in range(2):
        col = cols[2*i + j]
        axs[i,j].boxplot(df[col])
        axs[i,j].set_title(col)
plt.tight_layout()
plt.show()

# %%
s1 = np.random.normal(loc=0, scale=1, size=1000)
s2 = np.random.normal(loc=5, scale=0.5, size=1000)
s3 = np.random.normal(loc=10, scale=2, size=1000)

# %%
s1
# Out:
# array([ 1.51325223e+00, -1.42333588e-01, -1.39419961e-01,  1.17550754e+00,
#         1.18378901e+00,  6.83407261e-01, -1.21511360e+00,  5.31561240e-01,
#         2.45428983e-01,  2.51987804e-01,  1.74445999e+00, -9.58100168e-01,
#         1.82466896e+00, -1.67994538e+00, -1.11440892e+00,  5.91510269e-02,
#        -3.15701275e-01,  4.70432125e-01,  7.76392405e-01, -1.06462360e+00,
#        -1.82608938e-01,  2.11447859e-01, -1.33272526e+00, -2.07569925e-01,
#        -7.82921557e-03,  3.65266241e-01, -4.00027983e-01,  1.13252549e+00,
#        -9.86162926e-02, -2.11022193e-01, -1.58023773e+00, -9.29664224e-01,
#        -5.97903609e-01, -1.43297066e+00, -4.66958568e-01, -8.94144770e-01,
#        -3.31766905e+00,  8.95279584e-01,  1.19962940e+00,  3.81604602e-01,
#         9.01728639e-02, -3.74486196e-02, -2.33317403e+00, -6.69495842e-02,
#        -1.45310910e+00, -9.71479072e-01, -1.39758828e+00,  8.58920869e-02,
#         2.65068988e+00, -4.84919765e-01,  1.37009923e+00,  4.54701165e-01,
#         1.57855328e+00,  1.19618007e+00, -1.83917458e+00,  1.10938132e+00,
#         5.48177513e-01, -1.15172050e+00,  4.09715396e-01, -1.42798751e+00,
#         1.95893322e-01,  1.15820252e+00,  2.39352931e-01, -1.20713730e+00,
#        -2.97530198e-01,  3.48145445e-01,  8.18286831e-01,  2.00500696e-01,
#        -3.65539568e-01, -5.54164021e-01,  4.81704839e-01,  1.63450267e+00,
#         7.02061352e-01, -6.43266553e-01,  1.24111236e+00, -9.74133183e-02,
#         1.49453761e+00, -7.46196629e-02,  1.09352663e+00, -3.10489489e-01,
#        -1.44974517e-01,  1.44147588e+00, -1.27366510e+00,  2.40207427e-01,
#        -5.71490206e-01,  2.90422256e-01,  1.21942460e-01,  2.31755707e+00,
#         3.52612957e-01, -1.21310026e+00, -4.05337374e-01,  7.16788376e-01,
#        -3.08894406e-01,  7.17578257e-01,  1.37337350e+00,  9.74920051e-01,
#        -1.10593030e+00, -5.71189879e-01,  8.68732685e-02, -1.77979683e+00,
#         7.15636339e-01, -2.62947912e-01, -1.74116803e-01,  3.53890878e-01,
#        -5.87262826e-01,  1.51195385e+00,  7.54911381e-01, -1.31295611e+00,
#         5.47774019e-02, -5.34806996e-01,  8.06390994e-01,  7.49548145e-01,
#         1.37933813e+00, -4.71594614e-01, -2.75307015e-01,  2.38817242e-01,
#         3.50524693e-01, -6.46656280e-01,  7.14837742e-01, -7.31278394e-02,
#        -2.46222258e+00, -2.41123157e+00, -9.95946962e-01,  1.52789017e+00,
#         9.12009637e-01,  3.35331958e-01, -4.05626594e-01, -1.10882363e-01,
#         5.60160377e-01, -3.77318082e-01,  1.29472901e+00,  1.50937296e+00,
#         1.10333126e+00, -5.92018721e-01, -1.33800422e-01, -5.97708797e-02,
#         2.93062376e-01, -1.41083143e+00,  1.25425774e+00, -8.90276579e-01,
#         9.49562566e-01,  7.73583249e-01, -8.77727462e-02,  1.91760731e+00,
#        -6.95453479e-01,  8.11505682e-01, -6.32994904e-01,  2.17094869e-01,
#         2.92741077e-01, -1.82019942e-01, -3.14650567e-01,  5.86570107e-02,
#        -9.54325526e-01,  7.94839249e-01,  7.09195750e-01,  1.28805770e+00,
#         4.90699575e-01,  3.13194957e-01,  4.30574453e-01, -1.34409131e+00,
#        -6.28609939e-01, -8.48099380e-01, -2.29261999e+00, -4.11496946e-01,
#         4.47747386e-01,  1.16166271e-02, -4.07304467e-01, -1.73232877e+00,
#         3.09606748e-01, -4.00657115e-01,  3.62364517e-01, -2.05492217e+00,
#         1.00063841e+00,  6.75111991e-01, -4.01690135e-01, -4.86838715e-01,
#         1.17374755e+00,  2.23539887e-01,  1.61911298e-01, -1.22956211e+00,
#         1.62066986e+00,  1.67433640e+00, -1.07446972e-02,  1.34859674e+00,
#        -1.14862992e+00,  2.00154594e-02,  6.00061421e-01, -6.43121150e-01,
#        -5.92934368e-02,  4.78315041e-01,  2.24809771e-01,  5.17413236e-01,
#         6.01196120e-03, -6.96498621e-01, -2.25297460e+00,  2.04581849e-01,
#        -3.90632079e-01,  1.42211228e+00,  3.71039938e-01,  1.00160864e+00,
#        -6.19555740e-01,  1.44788617e-01, -2.25124778e-01,  1.13218552e+00,
#         8.15115785e-01,  1.31708250e+00,  1.38503188e+00,  1.63747733e-01,
#        -3.66712207e-01, -9.95205691e-01, -3.21942724e-01,  4.34026241e-02,
#        -2.47333672e-01,  2.21606445e+00, -7.51407652e-02, -9.97088752e-02,
#         1.96935055e-01,  1.56574952e-01,  8.44145630e-01,  1.01508587e+00,
#         8.36733931e-01, -1.69187807e-01, -7.19491116e-01,  1.36643132e-02,
#         9.44041321e-01, -1.15793998e+00,  5.18433366e-01, -6.69286606e-01,
#        -8.92160141e-02, -2.00360294e-01, -2.10668904e-01,  6.37670855e-01,
#         1.45386364e+00, -4.06279177e-01,  1.23790035e-01,  9.82679612e-01,
#        -7.36402290e-01,  3.70967513e-01,  1.27968935e+00, -4.16061951e-01,
#        -1.25701637e+00, -1.82001933e+00, -1.36439300e-01, -2.13042762e+00,
#        -5.80424935e-01, -7.13068071e-01,  5.34236507e-01,  2.93705121e-01,
#        -1.60542381e+00, -1.30389050e+00,  5.18209650e-01,  6.33242755e-01,
#         1.15262528e+00,  3.72233385e-01,  6.12246195e-01,  1.71027507e+00])

# %%
fig, axs = plt.subplots(1,3)
axs[0].hist(s1)
axs[0].set_title('s1')
axs[1].hist(s2)
axs[1].set_title('s2')
axs[2].hist(s3)
axs[2].set_title('s3')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.boxplot((s1,s2,s3))
plt.show()

# %%
df.origin.value_counts()
# Out:
# 1    249
# 3     79
# 2     70
# Name: origin, dtype: int64

# %% [markdown]
# #### origin의 값에 따른 mpg의 박스플롯

# %%
plt.boxplot([df[df.origin==1].mpg,
             df[df.origin==2].mpg,
             df[df.origin==3].mpg],
            labels=['USA', 'EU', 'JPN'])
plt.show()

# %%
plt.boxplot([df[df.origin==1].mpg,
             df[df.origin==2].mpg,
             df[df.origin==3].mpg],
            labels=['USA', 'EU', 'JPN'],
            vert=False)
plt.show()

# %%
plt.boxplot([df[df.origin==1].mpg,
             df[df.origin==2].mpg,
             df[df.origin==3].mpg],
            labels=['USA', 'EU', 'JPN'],
            vert=False, sym='+')
plt.show()

# %% [markdown]
# #### 문제. origin의 값에 따른 weight의 박스플롯과 displacement의 박스플롯 한 그림 내에 그리기

# %%
fig, axs = plt.subplots(2,1)

axs[0].boxplot([df[df.origin==1].weight,
             df[df.origin==2].weight,
             df[df.origin==3].weight],
            labels=['USA', 'EU', 'JPN'],
            vert=False, sym='+')
axs[0].set_title('Weight')


axs[1].boxplot([df[df.origin==1].displacement,
             df[df.origin==2].displacement,
             df[df.origin==3].displacement],
            labels=['USA', 'EU', 'JPN'],
            vert=False, sym='+')
axs[1].set_title('Displacement')

plt.show()

# %%
fig, axs = plt.subplots(2,1, tight_layout=True)

axs[0].boxplot([df[df.origin==1].weight,
             df[df.origin==2].weight,
             df[df.origin==3].weight],
            labels=['USA', 'EU', 'JPN'],
            vert=False, sym='+', notch=True)
axs[0].set_title('Weight')


axs[1].boxplot([df[df.origin==1].displacement,
             df[df.origin==2].displacement,
             df[df.origin==3].displacement],
            labels=['USA', 'EU', 'JPN'],
            vert=False, sym='+')
axs[1].set_title('Displacement')

plt.show()

# %% [markdown]
# ## 5. 파이차트 : pie()

# %% [markdown]
# - 범주형 데이터의 빈도(비율)을 비교하기 위해 사용하는 차트
# - 원의 형태를 유지할 수 있도록 다음 명령을 실행해야 함
#     - plt.axis('equal')
#     - 콘솔에서는 별 다른 변화 없으나 plot창에서는 필요함

# %%
size = [15,20,45,30]
labels = ['김밥', '김치찌게', '짜장면', '돈까스']

plt.title('선호하는 점심식사 메뉴')
plt.pie(size, labels=labels)
plt.show()

# %%
plt.title('선호하는 점심식사 메뉴')
plt.pie(size, labels=labels, startangle=90, radius=0.8)
plt.show()

# %%
plt.title('선호하는 점심식사 메뉴')
plt.pie(size, labels=labels, startangle=90,
        radius=0.8, explode=[0.2, 0, 0, 0])
plt.show()

# %%
plt.title('선호하는 점심식사 메뉴')
plt.pie(size, labels=labels, startangle=90,
        radius=0.8, explode=[0.2, 0, 0, 0],
        autopct='%.1f%%')
plt.show()

# %%
plt.title('선호하는 점심식사 메뉴')
plt.pie(size, labels=labels, startangle=90,
        radius=0.8, explode=[0.2, 0, 0, 0],
        autopct='%.1f%%',
        colors=['yellow','skyblue','gold','coral'])
plt.show()

# %% [markdown]
# #### 문제. auto 데이터셋에서  cylinders, origin에 대한 pie 표현

# %%
cyl = df.cylinders.value_counts().sort_index()
origin = df.origin.value_counts().sort_index()

# %%
origin
# Out:
# 1    249
# 2     70
# 3     79
# Name: origin, dtype: int64

# %%
fig, axs = plt.subplots(1,2, figsize=(6,3), tight_layout=True)
axs[0].pie(cyl, labels=cyl.index, startangle=90, autopct='%.1f%%')
axs[0].set_title('Pie chart : Cylinders')

axs[1].pie(origin, labels=['USA','EU','JPN'],
           startangle=90, autopct='%.1f%%')
axs[1].set_title('Pie chart : Weight')

plt.show()

# %%
plt.pie(origin, labels=['USA','EU','JPN'],
           startangle=90, autopct='%.1f%%')
plt.title('Pie chart : Weight')
plt.legend()
plt.show()

# %% [markdown]
# -----
